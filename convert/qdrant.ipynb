# %%
# %pip install sentence-transformers qdrant-client
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ---------------------------------------- 0.0/86.0 kB ? eta -:--:--
#      ---------------------------------------- 86.0/86.0 kB 5.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting qdrant-client
#   Downloading qdrant_client-1.6.4-py3-none-any.whl.metadata (9.0 kB)
# Collecting transformers<5.0.0,>=4.6.0 (from sentence-transformers)
#   Downloading transformers-4.35.0-py3-none-any.whl.metadata (123 kB)
#      ---------------------------------------- 0.0/123.1 kB ? eta -:--:--
#      -------------------------------------- 123.1/123.1 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (2.1.0)
# Requirement already satisfied: torchvision in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (0.16.0)
# Requirement already satisfied: numpy in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (1.26.1)
# Collecting scikit-learn (from sentence-transformers)
#   Downloading scikit_learn-1.3.2-cp310-cp310-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: scipy in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from sentence-transformers) (1.9.3)
# Collecting nltk (from sentence-transformers)
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#      -------- ------------------------------- 0.3/1.5 MB 9.9 MB/s eta 0:00:01
#      --------------- ------------------------ 0.6/1.5 MB 7.5 MB/s eta 0:00:01
#      ----------------------- ---------------- 0.9/1.5 MB 6.9 MB/s eta 0:00:01
#      ------------------------------ --------- 1.1/1.5 MB 6.6 MB/s eta 0:00:01
#      -------------------------------------- - 1.4/1.5 MB 6.6 MB/s eta 0:00:01
#      ---------------------------------------- 1.5/1.5 MB 6.0 MB/s eta 0:00:00
# Collecting sentencepiece (from sentence-transformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-win_amd64.whl (977 kB)
#      ---------------------------------------- 0.0/977.5 kB ? eta -:--:--
#      ----------- -------------------------- 286.7/977.5 kB 5.9 MB/s eta 0:00:01
#      ---------------------- --------------- 573.4/977.5 kB 6.1 MB/s eta 0:00:01
#      --------------------------------- ---- 849.9/977.5 kB 6.0 MB/s eta 0:00:01
#      -------------------------------------- 977.5/977.5 kB 5.6 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers)
#   Downloading huggingface_hub-0.19.0-py3-none-any.whl.metadata (13 kB)
# Collecting grpcio>=1.41.0 (from qdrant-client)
#   Downloading grpcio-1.59.2-cp310-cp310-win_amd64.whl.metadata (4.2 kB)
# Collecting grpcio-tools>=1.41.0 (from qdrant-client)
#   Downloading grpcio_tools-1.59.2-cp310-cp310-win_amd64.whl.metadata (6.4 kB)
# Collecting httpx>=0.14.0 (from httpx[http2]>=0.14.0->qdrant-client)
#   Downloading httpx-0.25.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from qdrant-client) (2.8.2)
# Collecting pydantic>=1.10.8 (from qdrant-client)
#   Downloading pydantic-2.4.2-py3-none-any.whl.metadata (158 kB)
#      ---------------------------------------- 0.0/158.6 kB ? eta -:--:--
#      ------------------------------------ - 153.6/158.6 kB 4.6 MB/s eta 0:00:01
#      ------------------------------------ - 153.6/158.6 kB 4.6 MB/s eta 0:00:01
#      -------------------------------------- 158.6/158.6 kB 1.2 MB/s eta 0:00:00
# Collecting urllib3<2.0.0,>=1.26.14 (from qdrant-client)
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl.metadata (48 kB)
#      ---------------------------------------- 0.0/48.9 kB ? eta -:--:--
#      ---------------------------------------- 48.9/48.9 kB 1.2 MB/s eta 0:00:00
# Collecting protobuf<5.0dev,>=4.21.6 (from grpcio-tools>=1.41.0->qdrant-client)
#   Downloading protobuf-4.25.0-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from grpcio-tools>=1.41.0->qdrant-client) (65.5.0)
# Requirement already satisfied: anyio in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.14.0->httpx[http2]>=0.14.0->qdrant-client) (3.6.2)
# Requirement already satisfied: certifi in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.14.0->httpx[http2]>=0.14.0->qdrant-client) (2022.9.24)
# Collecting httpcore (from httpx>=0.14.0->httpx[http2]>=0.14.0->qdrant-client)
#   Downloading httpcore-1.0.2-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.14.0->httpx[http2]>=0.14.0->qdrant-client) (3.4)
# Requirement already satisfied: sniffio in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.14.0->httpx[http2]>=0.14.0->qdrant-client) (1.3.0)
# Collecting h2<5,>=3 (from httpx[http2]>=0.14.0->qdrant-client)
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#      ---------------------------------------- 0.0/57.5 kB ? eta -:--:--
#      ---------------------------------------- 57.5/57.5 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in c:\users\victo\appdata\roaming\python\python310\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.10.7)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.9.2)
# Requirement already satisfied: requests in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.28.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.8.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.0)
# Requirement already satisfied: pywin32>=226 in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from portalocker<3.0.0,>=2.7.0->qdrant-client) (305)
# Collecting annotated-types>=0.4.0 (from pydantic>=1.10.8->qdrant-client)
#   Downloading annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.10.1 (from pydantic>=1.10.8->qdrant-client)
#   Downloading pydantic_core-2.10.1-cp310-none-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: sympy in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.6.0->sentence-transformers) (1.11.1)
# Requirement already satisfied: networkx in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: colorama in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from tqdm->sentence-transformers) (0.4.5)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.10.3)
# Collecting tokenizers<0.15,>=0.14 (from transformers<5.0.0,>=4.6.0->sentence-transformers)
#   Downloading tokenizers-0.14.1-cp310-none-win_amd64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers)
#   Downloading safetensors-0.4.0-cp310-none-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: click in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from nltk->sentence-transformers) (8.1.3)
# Collecting joblib (from nltk->sentence-transformers)
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->sentence-transformers)
#   Downloading threadpoolctl-3.2.0-py3-none-any.whl.metadata (10.0 kB)
# Collecting numpy (from sentence-transformers)
#   Downloading numpy-1.25.2-cp310-cp310-win_amd64.whl.metadata (5.7 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from torchvision->sentence-transformers) (9.4.0)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3->httpx[http2]>=0.14.0->qdrant-client)
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3->httpx[http2]>=0.14.0->qdrant-client)
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from httpcore->httpx>=0.14.0->httpx[http2]>=0.14.0->qdrant-client) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\victo\appdata\local\programs\python\python310\lib\site-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.2.1)
# Downloading qdrant_client-1.6.4-py3-none-any.whl (181 kB)
#    ---------------------------------------- 0.0/181.3 kB ? eta -:--:--
#    ------------------------------------- - 174.1/181.3 kB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 181.3/181.3 kB 3.6 MB/s eta 0:00:00
# Downloading grpcio-1.59.2-cp310-cp310-win_amd64.whl (3.7 MB)
#    ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.7 MB 11.1 MB/s eta 0:00:01
#    --------- ------------------------------ 0.9/3.7 MB 8.1 MB/s eta 0:00:01
#    -------------- ------------------------- 1.4/3.7 MB 7.3 MB/s eta 0:00:01
#    --------------------- ------------------ 1.9/3.7 MB 6.9 MB/s eta 0:00:01
#    -------------------------- ------------- 2.4/3.7 MB 6.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.7/3.7 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.1/3.7 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.1/3.7 MB 6.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.3/3.7 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  3.7/3.7 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 3.7/3.7 MB 5.3 MB/s eta 0:00:00
# Downloading grpcio_tools-1.59.2-cp310-cp310-win_amd64.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------------- ------------------------ 0.4/1.1 MB 8.3 MB/s eta 0:00:01
#    -------------------------------- ------- 0.9/1.1 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 6.1 MB/s eta 0:00:00
# Downloading httpx-0.25.1-py3-none-any.whl (75 kB)
#    ---------------------------------------- 0.0/75.0 kB ? eta -:--:--
#    ---------------------------------------- 75.0/75.0 kB 2.1 MB/s eta 0:00:00
# Downloading pydantic-2.4.2-py3-none-any.whl (395 kB)
#    ---------------------------------------- 0.0/395.8 kB ? eta -:--:--
#    ------------------------------------- -- 368.6/395.8 kB 7.8 MB/s eta 0:00:01
#    ---------------------------------------- 395.8/395.8 kB 6.2 MB/s eta 0:00:00
# Downloading pydantic_core-2.10.1-cp310-none-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/2.0 MB 6.5 MB/s eta 0:00:01
#    ------------ --------------------------- 0.6/2.0 MB 6.4 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.9/2.0 MB 6.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.1/2.0 MB 6.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.4/2.0 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.7/2.0 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.0 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 5.7 MB/s eta 0:00:00
# Downloading transformers-4.35.0-py3-none-any.whl (7.9 MB)
#    ---------------------------------------- 0.0/7.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.9 MB 8.3 MB/s eta 0:00:01
#    -- ------------------------------------- 0.6/7.9 MB 7.4 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.9/7.9 MB 7.3 MB/s eta 0:00:01
#    ------ --------------------------------- 1.2/7.9 MB 7.1 MB/s eta 0:00:01
#    ------- -------------------------------- 1.6/7.9 MB 7.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.0/7.9 MB 7.1 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.3/7.9 MB 6.9 MB/s eta 0:00:01
#    ------------- -------------------------- 2.6/7.9 MB 7.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.2/7.9 MB 7.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.5/7.9 MB 7.0 MB/s eta 0:00:01
#    ------------------- -------------------- 3.8/7.9 MB 7.0 MB/s eta 0:00:01
#    --------------------- ------------------ 4.2/7.9 MB 7.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/7.9 MB 7.0 MB/s eta 0:00:01
#    ------------------------ --------------- 4.9/7.9 MB 7.0 MB/s eta 0:00:01
#    -------------------------- ------------- 5.3/7.9 MB 7.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.6/7.9 MB 7.0 MB/s eta 0:00:01
#    ------------------------------ --------- 6.0/7.9 MB 7.0 MB/s eta 0:00:01
#    ------------------------------- -------- 6.3/7.9 MB 7.0 MB/s eta 0:00:01
#    --------------------------------- ------ 6.6/7.9 MB 7.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.0/7.9 MB 7.1 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/7.9 MB 7.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.7/7.9 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  7.9/7.9 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.9/7.9 MB 6.8 MB/s eta 0:00:00
# Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#    ---------------------------------------- 0.0/143.8 kB ? eta -:--:--
#    ---------------------------------------- 143.8/143.8 kB 8.3 MB/s eta 0:00:00
# Downloading scikit_learn-1.3.2-cp310-cp310-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.3 MB 7.7 MB/s eta 0:00:02
#    -- ------------------------------------- 0.6/9.3 MB 6.6 MB/s eta 0:00:02
#    --- ------------------------------------ 0.9/9.3 MB 6.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.3/9.3 MB 6.8 MB/s eta 0:00:02
#    ------ --------------------------------- 1.6/9.3 MB 6.8 MB/s eta 0:00:02
#    -------- ------------------------------- 1.9/9.3 MB 6.6 MB/s eta 0:00:02
#    -------- ------------------------------- 2.1/9.3 MB 6.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.4/9.3 MB 6.5 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.7/9.3 MB 6.5 MB/s eta 0:00:02
#    ------------- -------------------------- 3.1/9.3 MB 6.6 MB/s eta 0:00:01
#    -------------- ------------------------- 3.5/9.3 MB 6.7 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.8/9.3 MB 6.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.1/9.3 MB 6.9 MB/s eta 0:00:01
#    ------------------ --------------------- 4.4/9.3 MB 6.8 MB/s eta 0:00:01
#    -------------------- ------------------- 4.8/9.3 MB 6.9 MB/s eta 0:00:01
#    --------------------- ------------------ 5.1/9.3 MB 6.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 5.4/9.3 MB 6.9 MB/s eta 0:00:01
#    ------------------------ --------------- 5.7/9.3 MB 6.9 MB/s eta 0:00:01
#    -------------------------- ------------- 6.1/9.3 MB 6.9 MB/s eta 0:00:01
#    --------------------------- ------------ 6.4/9.3 MB 6.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.7/9.3 MB 6.9 MB/s eta 0:00:01
#    ------------------------------ --------- 7.0/9.3 MB 6.9 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.3 MB 6.8 MB/s eta 0:00:01
#    -------------------------------- ------- 7.6/9.3 MB 6.8 MB/s eta 0:00:01
#    --------------------------------- ------ 7.9/9.3 MB 6.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.2/9.3 MB 6.8 MB/s eta 0:00:01
#    ------------------------------------ --- 8.5/9.3 MB 6.8 MB/s eta 0:00:01
#    ------------------------------------- -- 8.8/9.3 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.1/9.3 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  9.2/9.3 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 6.6 MB/s eta 0:00:00
# Downloading numpy-1.25.2-cp310-cp310-win_amd64.whl (15.6 MB)
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/15.6 MB 19.2 MB/s eta 0:00:01
#    - -------------------------------------- 0.7/15.6 MB 9.1 MB/s eta 0:00:02
#    -- ------------------------------------- 1.1/15.6 MB 8.4 MB/s eta 0:00:02
#    --- ------------------------------------ 1.4/15.6 MB 7.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.7/15.6 MB 7.6 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.1/15.6 MB 7.8 MB/s eta 0:00:02
#    ------ --------------------------------- 2.4/15.6 MB 7.7 MB/s eta 0:00:02
#    ------- -------------------------------- 2.7/15.6 MB 7.6 MB/s eta 0:00:02
#    ------- -------------------------------- 2.9/15.6 MB 7.2 MB/s eta 0:00:02
#    -------- ------------------------------- 3.2/15.6 MB 7.1 MB/s eta 0:00:02
#    --------- ------------------------------ 3.6/15.6 MB 7.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.0/15.6 MB 7.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.3/15.6 MB 7.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.6/15.6 MB 7.2 MB/s eta 0:00:02
#    ------------ --------------------------- 4.9/15.6 MB 7.3 MB/s eta 0:00:02
#    ------------- -------------------------- 5.3/15.6 MB 7.2 MB/s eta 0:00:02
#    -------------- ------------------------- 5.6/15.6 MB 7.2 MB/s eta 0:00:02
#    --------------- ------------------------ 6.0/15.6 MB 7.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.3/15.6 MB 7.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 6.6/15.6 MB 7.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 6.9/15.6 MB 7.2 MB/s eta 0:00:02
#    ------------------ --------------------- 7.2/15.6 MB 7.2 MB/s eta 0:00:02
#    ------------------- -------------------- 7.6/15.6 MB 7.2 MB/s eta 0:00:02
#    -------------------- ------------------- 7.8/15.6 MB 7.2 MB/s eta 0:00:02
#    --------------------- ------------------ 8.2/15.6 MB 7.2 MB/s eta 0:00:02
#    --------------------- ------------------ 8.5/15.6 MB 7.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.8/15.6 MB 7.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 9.2/15.6 MB 7.1 MB/s eta 0:00:01
#    ------------------------ --------------- 9.5/15.6 MB 7.1 MB/s eta 0:00:01
#    ------------------------- -------------- 9.8/15.6 MB 7.1 MB/s eta 0:00:01
#    -------------------------- ------------- 10.2/15.6 MB 7.2 MB/s eta 0:00:01
#    --------------------------- ------------ 10.5/15.6 MB 7.0 MB/s eta 0:00:01
#    --------------------------- ------------ 10.8/15.6 MB 7.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.2/15.6 MB 7.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 11.5/15.6 MB 7.0 MB/s eta 0:00:01
#    ------------------------------ --------- 12.0/15.6 MB 7.0 MB/s eta 0:00:01
#    ------------------------------- -------- 12.4/15.6 MB 7.0 MB/s eta 0:00:01
#    --------------------------------- ------ 12.9/15.6 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.2/15.6 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.6/15.6 MB 7.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 13.9/15.6 MB 7.1 MB/s eta 0:00:01
#    ------------------------------------ --- 14.3/15.6 MB 7.0 MB/s eta 0:00:01
#    ------------------------------------- -- 14.6/15.6 MB 7.0 MB/s eta 0:00:01
#    -------------------------------------- - 15.0/15.6 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  15.3/15.6 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  15.6/15.6 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 15.6/15.6 MB 6.8 MB/s eta 0:00:00
# Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading joblib-1.3.2-py3-none-any.whl (302 kB)
#    ---------------------------------------- 0.0/302.2 kB ? eta -:--:--
#    ---------------------------------------  297.0/302.2 kB 9.2 MB/s eta 0:00:01
#    ---------------------------------------- 302.2/302.2 kB 4.7 MB/s eta 0:00:00
# Downloading protobuf-4.25.0-cp310-abi3-win_amd64.whl (413 kB)
#    ---------------------------------------- 0.0/413.2 kB ? eta -:--:--
#    ---------------------------------------  409.6/413.2 kB 8.5 MB/s eta 0:00:01
#    ---------------------------------------- 413.2/413.2 kB 5.2 MB/s eta 0:00:00
# Downloading safetensors-0.4.0-cp310-none-win_amd64.whl (277 kB)
#    ---------------------------------------- 0.0/277.4 kB ? eta -:--:--
#    ---------------------------------------- 277.4/277.4 kB 5.7 MB/s eta 0:00:00
# Downloading threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Downloading tokenizers-0.14.1-cp310-none-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 8.0 MB/s eta 0:00:01
#    ------------------ --------------------- 1.0/2.2 MB 8.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.5/2.2 MB 8.0 MB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 6.7 MB/s eta 0:00:00
# Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#    ---------------------------------------- 0.0/295.0 kB ? eta -:--:--
#    ------------------------------------- -- 276.5/295.0 kB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 295.0/295.0 kB 3.7 MB/s eta 0:00:00
# Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#    ---------------------------------------- 0.0/76.9 kB ? eta -:--:--
#    ---------------------------------------- 76.9/76.9 kB 4.2 MB/s eta 0:00:00
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (pyproject.toml): started
#   Building wheel for sentence-transformers (pyproject.toml): finished with status 'done'
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125953 sha256=5149710d8687486ed6ccb583934a74b2cf4e84c5a478078a2cc46c3beb4139c4
#   Stored in directory: c:\users\victo\appdata\local\pip\cache\wheels\62\f2\10\1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: sentencepiece, urllib3, threadpoolctl, safetensors, pydantic-core, protobuf, numpy, joblib, hyperframe, httpcore, hpack, grpcio, annotated-types, pydantic, nltk, httpx, h2, grpcio-tools, scikit-learn, huggingface-hub, tokenizers, qdrant-client, transformers, sentence-transformers
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.12
#     Uninstalling urllib3-1.26.12:
#       Successfully uninstalled urllib3-1.26.12
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.1
#     Uninstalling numpy-1.26.1:
#       Successfully uninstalled numpy-1.26.1
# Successfully installed annotated-types-0.6.0 grpcio-1.59.2 grpcio-tools-1.59.2 h2-4.1.0 hpack-4.0.0 httpcore-1.0.2 httpx-0.25.1 huggingface-hub-0.17.3 hyperframe-6.0.1 joblib-1.3.2 nltk-3.8.1 numpy-1.25.2 protobuf-4.25.0 pydantic-2.4.2 pydantic-core-2.10.1 qdrant-client-1.6.4 safetensors-0.4.0 scikit-learn-1.3.2 sentence-transformers-2.2.2 sentencepiece-0.1.99 threadpoolctl-3.2.0 tokenizers-0.14.1 transformers-4.35.0 urllib3-1.26.18
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\victo\AppData\Local\Programs\Python\Python310\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\victo\AppData\Local\Programs\Python\Python310\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
# WARNING: There was an error checking the latest version of pip.

# %%
from qdrant_client import models, QdrantClient
from sentence_transformers import SentenceTransformer

# %%
encoder = SentenceTransformer("all-MiniLM-L6-v2")

# %%
documents = [
    {
        "name": "The Time Machine",
        "description": "A man travels through time and witnesses the evolution of humanity.",
        "author": "H.G. Wells",
        "year": 1895,
    },
    {
        "name": "Ender's Game",
        "description": "A young boy is trained to become a military leader in a war against an alien race.",
        "author": "Orson Scott Card",
        "year": 1985,
    },
    {
        "name": "Brave New World",
        "description": "A dystopian society where people are genetically engineered and conditioned to conform to a strict social hierarchy.",
        "author": "Aldous Huxley",
        "year": 1932,
    },
    {
        "name": "The Hitchhiker's Guide to the Galaxy",
        "description": "A comedic science fiction series following the misadventures of an unwitting human and his alien friend.",
        "author": "Douglas Adams",
        "year": 1979,
    },
    {
        "name": "Dune",
        "description": "A desert planet is the site of political intrigue and power struggles.",
        "author": "Frank Herbert",
        "year": 1965,
    },
    {
        "name": "Foundation",
        "description": "A mathematician develops a science to predict the future of humanity and works to save civilization from collapse.",
        "author": "Isaac Asimov",
        "year": 1951,
    },
    {
        "name": "Snow Crash",
        "description": "A futuristic world where the internet has evolved into a virtual reality metaverse.",
        "author": "Neal Stephenson",
        "year": 1992,
    },
    {
        "name": "Neuromancer",
        "description": "A hacker is hired to pull off a near-impossible hack and gets pulled into a web of intrigue.",
        "author": "William Gibson",
        "year": 1984,
    },
    {
        "name": "The War of the Worlds",
        "description": "A Martian invasion of Earth throws humanity into chaos.",
        "author": "H.G. Wells",
        "year": 1898,
    },
    {
        "name": "The Hunger Games",
        "description": "A dystopian society where teenagers are forced to fight to the death in a televised spectacle.",
        "author": "Suzanne Collins",
        "year": 2008,
    },
    {
        "name": "The Andromeda Strain",
        "description": "A deadly virus from outer space threatens to wipe out humanity.",
        "author": "Michael Crichton",
        "year": 1969,
    },
    {
        "name": "The Left Hand of Darkness",
        "description": "A human ambassador is sent to a planet where the inhabitants are genderless and can change gender at will.",
        "author": "Ursula K. Le Guin",
        "year": 1969,
    },
    {
        "name": "The Three-Body Problem",
        "description": "Humans encounter an alien civilization that lives in a dying system.",
        "author": "Liu Cixin",
        "year": 2008,
    },
]

# %%
qdrant = QdrantClient(":memory:")

# %%
qdrant.recreate_collection(
    collection_name="my_books",
    vectors_config=models.VectorParams(
        size=encoder.get_sentence_embedding_dimension(),  # Vector size is defined by used model
        distance=models.Distance.COSINE,
    ),
    recreate_collection=True,
)

# %%
qdrant.upload_records(
    collection_name="my_books",
    records=[
        models.Record(
            id=idx, vector=encoder.encode(doc["description"]).tolist(), payload=doc
        )
        for idx, doc in enumerate(documents)
    ],
)

# %%
hits = qdrant.search(
    collection_name="my_books",
    query_vector=encoder.encode("alien invasion").tolist(),
    limit=3,
)
for hit in hits:
    print(hit.payload, "score:", hit.score)

# %%
hits = qdrant.search(
    collection_name="my_books",
    query_vector=encoder.encode("alien invasion").tolist(),
    query_filter=models.Filter(
        must=[models.FieldCondition(key="year", range=models.Range(gte=2000))]
    ),
    limit=1,
)
for hit in hits:
    print(hit.payload, "score:", hit.score)
